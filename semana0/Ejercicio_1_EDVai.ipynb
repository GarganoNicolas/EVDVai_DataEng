# %% [markdown]
# <a href="https://colab.research.google.com/github/GarganoNicolas/EVDVai_DataEngTP1/blob/main/Ejercicio_1_EDVai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1.Importaciones de librerias

# %%
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Análisis Exploratorio de datos

# %% [markdown]
# ### 2.1 - Carga de los datos

# %%
# Lee el archivo Excel
excel_file = pd.ExcelFile('Utimas_Desvinculaciones.xlsx')

# Obtiene los nombres de las hojas y cuenta cuántas hay
cantidad_hojas = len(excel_file.sheet_names)

# Muestra la cantidad de hojas
print(f"El archivo Excel tiene {cantidad_hojas} hojas.")

print()

# Muestra los nombres de las hojas
print("Nombres de las hojas en el archivo Excel:")
print()
for nombre in excel_file.sheet_names:
    print(nombre)
# Out:
# El archivo Excel tiene 3 hojas.
#
# Nombres de las hojas en el archivo Excel:
#
# Row data
# Rangos
# Managers

# %%
# Lee el archivo Excel, leo los datos de cada hoja del archivo excel

excel_file = pd.ExcelFile('Utimas_Desvinculaciones.xlsx')

# Crea un diccionario para almacenar los DataFrames de cada hoja

dfs = {}

# Itera sobre cada hoja y guarda los datos en el diccionario 'dfs'

for sheet_name in excel_file.sheet_names:
    dfs[sheet_name] = excel_file.parse(sheet_name)

# Accede a las hojas específicas y asígnalas a variables individuales

data = dfs['Row data']
df_Rangos = dfs['Rangos']
df_Managers = dfs['Managers']

# Ahora puedes usar 'data', 'df_Rangos' y 'df_Managers' como variables independientes

# %% [markdown]
# ### 2.2 Exploramos la información

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  30 non-null     int64
#  1   Nombre              30 non-null     object
#  2   Apellido            30 non-null     object
#  3   Area                30 non-null     object
#  4   Fecha comienzo      30 non-null     datetime64[ns]
#  5   Fecha fin           30 non-null     datetime64[ns]
#  6   Nivel               30 non-null     object
#  7   Grupo recruitment   30 non-null     object
#  8   Tiempo recruitment  30 non-null     int64
#  9   Rango Salarial      30 non-null     object
#  10  RS competencia      30 non-null     object
#  11  Manager             30 non-null     int64
#  12  Realizo Cursos      30 non-null     object
# dtypes: datetime64[ns](2), int64(3), object(8)
# memory usage: 3.2+ KB

# %%
data.shape
# Out:
# (30, 13)

# %%
data.sample(5)
# Out:
#     Id    Nombre  Apellido        Area Fecha comienzo  Fecha fin Nivel  \
# 8   24   Micaela     Pauls  Producción     2019-01-07 2021-12-31    N6
# 26  21  Cristian    Martin     Compras     2017-11-06 2020-12-31    N5
# 17  25  Carolina  Petersen      Ventas     2021-07-05 2022-02-28    N7
# 22  12      Luis   Sánchez      Ventas     2020-07-13 2020-12-31    N5
# 12   2     Pedro     Lujan     Compras     2017-03-06 2021-12-31    N3
#
#    Grupo recruitment  Tiempo recruitment Rango Salarial RS competencia  \
# 8            Grupo A                   5        Rango 6        Rango 6
# 26           Grupo C                   4        Rango 6        Rango 5
# 17           Grupo B                   4        Rango 6        Rango 6
# 22           Grupo C                   5        Rango 6        Rango 6
# 12           Grupo B                   3        Rango 2        Rango 2
#
#     Manager Realizo Cursos
# 8         4             SI
# 26        2             SI
# ...

# %%
df_Rangos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rango   10 non-null     object
#  1   desde   10 non-null     int64
#  2   hasta   10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 368.0+ bytes

# %%
df_Rangos.shape
# Out:
# (10, 3)

# %%
df_Rangos.head(10)
# Out:
#       Rango   desde    hasta
# 0   Rango 1  150000   200000
# 1   Rango 2  200001   250000
# 2   Rango 3  250001   300000
# 3   Rango 4  300001   350000
# 4   Rango 5  350001   400000
# 5   Rango 6  400001   500000
# 6   Rango 7  500001   600000
# 7   Rango 8  600001   700000
# 8   Rango 9  700001   800000
# 9  Rango 10  800001  1000000

# %%
df_Managers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Id        10 non-null     int64
#  1   Nombre    10 non-null     object
#  2   Apellido  10 non-null     object
# dtypes: int64(1), object(2)
# memory usage: 368.0+ bytes

# %%
df_Managers.shape
# Out:
# (10, 3)

# %%
df_Managers.head(10)
# Out:
#    Id     Nombre  Apellido
# 0   1    Rolando     Casas
# 1   2     Marina    Pitana
# 2   3       José  Feligres
# 3   4     Miriam    Pisani
# 4   5  Alejandro  Pitorino
# 5   6      Sonia  Kamlasky
# 6   7     Martín    Viglia
# 7   8    Ricardo   Ronaldo
# 8   9     Vanina  Quintana
# 9  10     Daniel   Quiroga

# %% [markdown]
# ### 2.3 - Datos Nulos y Duplicados

# %%
# Contar el número de valores nulos en cada columna, usando isna()

valores_faltantes = data.isna().sum()
valores_faltantes
# Out:
# Id                    0
# Nombre                0
# Apellido              0
# Area                  0
# Fecha comienzo        0
# Fecha fin             0
# Nivel                 0
# Grupo recruitment     0
# Tiempo recruitment    0
# Rango Salarial        0
# RS competencia        0
# Manager               0
# Realizo Cursos        0
# dtype: int64

# %%
# Contar el número de valores nulos en cada columna, usando isnull()

valores_nulos = (data.isnull() | (data == '')).sum()
valores_nulos
# Out:
# Id                    0
# Nombre                0
# Apellido              0
# Area                  0
# Fecha comienzo        0
# Fecha fin             0
# Nivel                 0
# Grupo recruitment     0
# Tiempo recruitment    0
# Rango Salarial        0
# RS competencia        0
# Manager               0
# Realizo Cursos        0
# dtype: int64

# %%
# Calcular la cantidad de filas duplicadas en el DataFrame
cantidad_duplicados = data.duplicated().sum()

# Mostrar la cantidad de filas duplicadas
print(f"Cantidad de filas duplicadas: {cantidad_duplicados}")
# Out:
# Cantidad de filas duplicadas: 0

# %% [markdown]
# ### 2.4 - Limpieza y transformación de los datos

# %%
# Convierte la columna "Fecha comienzo" a tipo datetime (CAMBIO DE FORMATO)

data['Fecha comienzo'] = pd.to_datetime(data['Fecha comienzo'], errors='coerce')

# Formatea la columna "Fecha comienzo" con el nuevo formato "dia-mes-año"
data['Fecha comienzo'] = data['Fecha comienzo'].dt.strftime('%d-%m-%Y')

# %%
data.head()
# Out:
#    Id     Nombre   Apellido     Area Fecha comienzo  Fecha fin Nivel  \
# 0   4  Sebastian   González  Legales     07-05-2018 2021-05-30    N2
# 1   7   Anabella  Fernández   Ventas     06-07-2020 2021-03-31    N4
# 2   8  Francesca      López  Compras     02-01-2017 2021-06-30    N3
# 3  10        Ana       Diaz       IT     06-03-2017 2020-11-30    N4
# 4  13  Alejandro     Romero       IT     01-06-2020 2022-02-28    N3
#
#   Grupo recruitment  Tiempo recruitment Rango Salarial RS competencia  \
# 0           Grupo A                   4        Rango 2        Rango 2
# 1           Grupo A                   3        Rango 4        Rango 4
# 2           Grupo A                   4        Rango 3        Rango 3
# 3           Grupo A                   3        Rango 3        Rango 3
# 4           Grupo A                   3        Rango 4        Rango 3
#
#    Manager Realizo Cursos
# 0        3             SI
# 1        8             NO
# 2        2             SI
# ...

# %%
# Convierte la columna "Fecha fin" a tipo datetime (CAMBIO DE FORMATO)

data['Fecha fin'] = pd.to_datetime(data['Fecha fin'], errors='coerce')

# Formatea la columna "Fecha fin" con el nuevo formato "dia-mes-año"
data['Fecha fin'] = data['Fecha fin'].dt.strftime('%d-%m-%Y')

# %%
data.head()
# Out:
#    Id     Nombre   Apellido     Area Fecha comienzo   Fecha fin Nivel  \
# 0   4  Sebastian   González  Legales     07-05-2018  30-05-2021    N2
# 1   7   Anabella  Fernández   Ventas     06-07-2020  31-03-2021    N4
# 2   8  Francesca      López  Compras     02-01-2017  30-06-2021    N3
# 3  10        Ana       Diaz       IT     06-03-2017  30-11-2020    N4
# 4  13  Alejandro     Romero       IT     01-06-2020  28-02-2022    N3
#
#   Grupo recruitment  Tiempo recruitment Rango Salarial RS competencia  \
# 0           Grupo A                   4        Rango 2        Rango 2
# 1           Grupo A                   3        Rango 4        Rango 4
# 2           Grupo A                   4        Rango 3        Rango 3
# 3           Grupo A                   3        Rango 3        Rango 3
# 4           Grupo A                   3        Rango 4        Rango 3
#
#    Manager Realizo Cursos
# 0        3             SI
# 1        8             NO
# 2        2             SI
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  30 non-null     int64
#  1   Nombre              30 non-null     object
#  2   Apellido            30 non-null     object
#  3   Area                30 non-null     object
#  4   Fecha comienzo      30 non-null     object
#  5   Fecha fin           30 non-null     object
#  6   Nivel               30 non-null     object
#  7   Grupo recruitment   30 non-null     object
#  8   Tiempo recruitment  30 non-null     int64
#  9   Rango Salarial      30 non-null     object
#  10  RS competencia      30 non-null     object
#  11  Manager             30 non-null     int64
#  12  Realizo Cursos      30 non-null     object
# dtypes: int64(3), object(10)
# memory usage: 3.2+ KB

# %%
data['Fecha comienzo'] = pd.to_datetime(data['Fecha comienzo'], format='%d-%m-%Y')
data['Fecha fin'] = pd.to_datetime(data['Fecha fin'], format='%d-%m-%Y')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  30 non-null     int64
#  1   Nombre              30 non-null     object
#  2   Apellido            30 non-null     object
#  3   Area                30 non-null     object
#  4   Fecha comienzo      30 non-null     datetime64[ns]
#  5   Fecha fin           30 non-null     datetime64[ns]
#  6   Nivel               30 non-null     object
#  7   Grupo recruitment   30 non-null     object
#  8   Tiempo recruitment  30 non-null     int64
#  9   Rango Salarial      30 non-null     object
#  10  RS competencia      30 non-null     object
#  11  Manager             30 non-null     int64
#  12  Realizo Cursos      30 non-null     object
# dtypes: datetime64[ns](2), int64(3), object(8)
# memory usage: 3.2+ KB

# %%
# Convertir la columna "Realizo Cursos" a valores booleanos
data['Realizo Cursos'] = [bool(val) for val in data['Realizo Cursos']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  30 non-null     int64
#  1   Nombre              30 non-null     object
#  2   Apellido            30 non-null     object
#  3   Area                30 non-null     object
#  4   Fecha comienzo      30 non-null     datetime64[ns]
#  5   Fecha fin           30 non-null     datetime64[ns]
#  6   Nivel               30 non-null     object
#  7   Grupo recruitment   30 non-null     object
#  8   Tiempo recruitment  30 non-null     int64
#  9   Rango Salarial      30 non-null     object
#  10  RS competencia      30 non-null     object
#  11  Manager             30 non-null     int64
#  12  Realizo Cursos      30 non-null     bool
#  13  Año                 30 non-null     int64
# dtypes: bool(1), datetime64[ns](2), int64(4), object(7)
# memory usage: 3.2+ KB

# %% [markdown]
# # 3 - Analisis de Datos

# %%
data.head(30)
# Out:
#     Id     Nombre   Apellido        Area Fecha comienzo   Fecha fin Nivel  \
# 0    4  Sebastian   González     Legales     07-05-2018  30-05-2021    N2
# 1    7   Anabella  Fernández      Ventas     06-07-2020  31-03-2021    N4
# 2    8  Francesca      López     Compras     02-01-2017  30-06-2021    N3
# 3   10        Ana       Diaz          IT     06-03-2017  30-11-2020    N4
# 4   13  Alejandro     Romero          IT     01-06-2020  28-02-2022    N3
# 5   15     Analia       Sosa     Compras     01-10-2018  30-11-2021    N4
# 6   17  Guillermo    Ramírez          IT     06-01-2020  31-05-2022    N2
# 7   19      Rocio       Ruiz   Auditoria     05-02-2018  30-01-2021    N4
# 8   24    Micaela      Pauls  Producción     07-01-2019  31-12-2021    N6
# 9   27    Rodrigo    Molinas     Compras     03-06-2019  30-04-2022    N2
# 10  28    Martina   Oliviera  Producción     06-01-2020  30-06-2022    N7
# 11   1     Romina      Brito   Marketing     05-03-2018  31-12-2018    N3
# ...

# %%
# chequeo typo de datos
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  30 non-null     int64
#  1   Nombre              30 non-null     object
#  2   Apellido            30 non-null     object
#  3   Area                30 non-null     object
#  4   Fecha comienzo      30 non-null     object
#  5   Fecha fin           30 non-null     object
#  6   Nivel               30 non-null     object
#  7   Grupo recruitment   30 non-null     object
#  8   Tiempo recruitment  30 non-null     int64
#  9   Rango Salarial      30 non-null     object
#  10  RS competencia      30 non-null     object
#  11  Manager             30 non-null     int64
#  12  Realizo Cursos      30 non-null     object
# dtypes: int64(3), object(10)
# memory usage: 3.2+ KB

# %% [markdown]
# **Cantidad de personas desvinculadas por año**

# %%
# Extraer el año de la fecha de fin
data['Año'] = data['Fecha fin'].dt.year

# Contar la cantidad de personas por año
conteo_por_año = data.groupby('Año').size()

# Mostrar los resultados
print(conteo_por_año)

# Crear el gráfico de barras
plt.bar(conteo_por_año.index, conteo_por_año.values)

# Agregar etiquetas y título
plt.xlabel('Año')
plt.ylabel('Cantidad de personas')
plt.title('Cantidad de personas Desvinculadas por año')

# Mostrar el gráfico
plt.show()
# Out:
# Año
# 2017     1
# 2018     1
# 2019     2
# 2020     5
# 2021    11
# 2022    10
# dtype: int64

# %% [markdown]
# **Cantidad de personas por Manager**

# %%
# Contar la cantidad de personas por manager
conteo_por_manager = data['Manager'].value_counts()

# Graficar el gráfico de barras
conteo_por_manager.plot(kind='bar')

# Agregar etiquetas y título
plt.xlabel('Manager')
plt.ylabel('Cantidad de personas')
plt.title('Cantidad de personas por manager')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# **Cantidad de personas por año y Manager**

# %%
# Contar la cantidad de personas por año y por manager
conteo_por_año_manager = data.groupby(['Año', 'Manager']).size().unstack()

# Graficar el gráfico de barras apiladas
conteo_por_año_manager.plot(kind='bar', stacked=True)

# Agregar etiquetas y título
plt.xlabel('Año')
plt.ylabel('Cantidad de personas')
plt.title('Cantidad de personas por año y manager')

# Mostrar la leyenda
plt.legend(title='Manager')

# Mostrar el gráfico
plt.show()

# %%
# Contar el número de personas por manager y año
conteo_por_manager_y_año = {}
for manager, año in zip(data['Manager'], data['Año']):
    if manager not in conteo_por_manager_y_año:
        conteo_por_manager_y_año[manager] = {}
    if año not in conteo_por_manager_y_año[manager]:
        conteo_por_manager_y_año[manager][año] = 0
    conteo_por_manager_y_año[manager][año] += 1



# Preparar los datos para graficar
managers = sorted(conteo_por_manager_y_año.keys())
años = sorted(set(año for manager in conteo_por_manager_y_año for año in conteo_por_manager_y_año[manager]))
datos_grafica = [[conteo_por_manager_y_año[manager].get(año, 0) for año in años] for manager in managers]

# Graficar
plt.figure(figsize=(10, 6))
for i, manager in enumerate(managers):
    plt.bar(años, datos_grafica[i], label=f'Manager {manager}', alpha=0.7)
plt.xlabel('Año')
plt.ylabel('Número de Personas')
plt.title('Número de Personas por Manager y Año')
plt.legend(title='Manager', loc='upper left')
plt.grid(True)
plt.show()

# %%
# Contar la cantidad de personas que realizaron cursos y las que no
realizo_cursos = sum(1 for curso in data['Realizo Cursos'] if curso == 'SI')
no_realizo_cursos = sum(1 for curso in data['Realizo Cursos'] if curso == 'NO')

# Mostrar los datos
print("Cantidad de personas que realizaron cursos:", realizo_cursos)
print("Cantidad de personas que no realizaron cursos:", no_realizo_cursos)

# Graficar
fig, ax = plt.subplots()
ax.pie([realizo_cursos, no_realizo_cursos], labels=['Realizó Curso', 'No Realizó Curso'], autopct='%1.1f%%', startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.title('Proporción de Personas que Realizaron y No Realizaron Cursos')
plt.show()
# Out:
# Cantidad de personas que realizaron cursos: 20
# Cantidad de personas que no realizaron cursos: 10

# %%
# Contar la cantidad de personas con rango salarial mayor que la competencia
mayor_que_competencia = sum(1 for rs, rs_competencia in zip(data['Rango Salarial'], data['RS competencia']) if rs > rs_competencia)

# Calcular la cantidad de personas con igual o menor rango salarial que la competencia
igual_o_menor_que_competencia = len(data['Rango Salarial']) - mayor_que_competencia

# Mostrar los datos
print("Cantidad de personas con rango salarial mayor que la competencia:", mayor_que_competencia)
print("Cantidad de personas con igual o menor rango salarial que la competencia:", igual_o_menor_que_competencia)

# Graficar
plt.bar(['Mayor que Competencia', 'Igual o Menor que Competencia'], [mayor_que_competencia, igual_o_menor_que_competencia])
plt.xlabel('Comparación')
plt.ylabel('Cantidad de Personas')
plt.title('Comparación del Rango Salarial con la Competencia')
plt.show()
# Out:
# Cantidad de personas con rango salarial mayor que la competencia: 3
# Cantidad de personas con igual o menor rango salarial que la competencia: 27

# %%
# Contar la cantidad de personas por área
conteo_por_area = {}
for area in data['Area']:
    if area not in conteo_por_area:
        conteo_por_area[area] = 0
    conteo_por_area[area] += 1

# Mostrar los datos
print("Cantidad de personas por área:")
for area, cantidad in conteo_por_area.items():
    print(f"{area}: {cantidad}")

# Graficar
plt.bar(conteo_por_area.keys(), conteo_por_area.values())
plt.xlabel('Área')
plt.ylabel('Cantidad de Personas')
plt.title('Cantidad de Personas por Área')
plt.xticks(rotation=45, ha='right')  # Rotar las etiquetas del eje x para mejor visualización
plt.show()
# Out:
# Cantidad de personas por área:
# Legales: 1
# Ventas: 6
# Compras: 5
# IT: 8
# Auditoria: 2
# Producción: 4
# Marketing: 4
